# %%
import pandas as pd 
url = 'https://raw.githubusercontent.com/roberthsu2003/PythonForDataAnalysis/master/pandas%E7%9A%84%E6%AA%94%E6%A1%88%E5%AD%98%E5%8F%96/%E5%90%84%E9%84%89%E9%8E%AE%E5%B8%82%E5%8D%80%E4%BA%BA%E5%8F%A3%E5%AF%86%E5%BA%A6.csv'
dataFrame = pd.read_csv(url)
dataFrame
# Out:
#     statistic_yyy                                            site_id  \
# 0             統計年                                                區域別
# 1             106                                             新北市板橋區
# 2             106                                             新北市三重區
# 3             106                                             新北市中和區
# 4             106                                             新北市永和區
# ..            ...                                                ...
# 371           NaN                                                NaN
# 372           NaN                           說明：1.人口密度係指每單位土地面積內之人口數。
# 373           NaN  2.96年12月起，我國土地面積增列東沙群島(2.38平方公里)及南沙群島(0.4896平方公里)
# 374           NaN           ，由高雄市代管；原金門縣烏坵鄉面積，因重測由2.6平方公里修正為1.2平方公里。
# 375           NaN           3.104年12月南沙太平島交通基礎整建工程竣工，增加面積0.0149平方公里。
#
#     people_total     area population_density
# 0          年底人口數     土地面積               人口密度
# 1         551480  23.1373              23835
# 2         387484   16.317              23747
# 3         413590   20.144              20532
# 4         222585   5.7138              38956
# ..           ...      ...                ...
# 371          NaN      NaN                NaN
# 372          NaN      NaN                NaN
# 373          NaN      NaN                NaN
# 374          NaN      NaN                NaN
# 375          NaN      NaN                NaN
#
# [376 rows x 5 columns]

# %%
dataFrame
dataFrame.columns = dataFrame.iloc[0]
dataFrame1=dataFrame.drop(index=0)
dataFrame2=dataFrame1.drop(index=[371,372,373,374,375])
dataFrame2
# Out:
# 0    統計年     區域別   年底人口數     土地面積   人口密度
# 1    106  新北市板橋區  551480  23.1373  23835
# 2    106  新北市三重區  387484   16.317  23747
# 3    106  新北市中和區  413590   20.144  20532
# 4    106  新北市永和區  222585   5.7138  38956
# 5    106  新北市新莊區  416524  19.7383  21102
# ..   ...     ...     ...      ...    ...
# 366  106  連江縣北竿鄉    2360      9.9    238
# 367  106  連江縣莒光鄉    1624      4.7    346
# 368  106  連江縣東引鄉    1352      3.8    356
# 369  106    東沙群島      …      2.38     …
# 370  106    南沙群島      …    0.5045     …
#
# [370 rows x 5 columns]

# %%
import psycopg2
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://roberthsu:VE3oDznNjfVtb1DuC8vxKTJvSSH5m8JN@dpg-cl5g4rl6fh7c73empfq0-a.singapore-postgres.render.com/maindb_s1l")
dataFrame2.to_sql("106人口密度",engine,if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspaces/_112_python_chihlee_kelly/lesson11_2.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://codespaces%2Bspecial-zebra-5gqw4679qxjph4v5g/workspaces/_112_python_chihlee_kelly/lesson11_2.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import psycopg2
#       <a href='vscode-notebook-cell://codespaces%2Bspecial-zebra-5gqw4679qxjph4v5g/workspaces/_112_python_chihlee_kelly/lesson11_2.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> from sqlalchemy import create_engine
#       <a href='vscode-notebook-cell://codespaces%2Bspecial-zebra-5gqw4679qxjph4v5g/workspaces/_112_python_chihlee_kelly/lesson11_2.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> engine = create_engine("postgresql+psycopg2://roberthsu:VE3oDznNjfVtb1DuC8vxKTJvSSH5m8JN@dpg-cl5g4rl6fh7c73empfq0-a.singapore-postgres.render.com/maindb_s1l")
#
# ModuleNotFoundError: No module named 'psycopg2'
